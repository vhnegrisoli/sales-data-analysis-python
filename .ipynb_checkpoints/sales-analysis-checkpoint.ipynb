# %%
# Importando as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Realizando a leitura do dataset em CSV e visualizando o Dataset
df = pd.read_csv('data/sales_data_sample.csv')

# Visualiza as colunas e os 5 primeiros itens
df.head(5)

# Visualiza os tipos de dados
df.dtypes

# Visualiza as colunas os 3 últimos itens
df.tail(3)

# Ordena o dataset pela coluna ORDERNUMBER
df.sort_values(by='ORDERNUMBER')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 578         10100               30     100.00                3  5151.00
# 2024        10100               49      34.47                1  1689.03
# 680         10100               50      67.80                2  3390.00
# 1267        10100               22      86.51                4  1903.22
# 728         10101               25     100.00                4  3782.00
# ...           ...              ...        ...              ...      ...
# 2405        10425               18     100.00                2  1895.94
# 393         10425               33     100.00                4  4692.60
# 160         10425               38     100.00               12  5894.94
# 780         10425               19      49.22               10   935.18
# 727         10425               38      99.41                7  3777.58
#
#            ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 578    1/6/2003 0:00     Shipped       1         1     2003  ...
# 2024   1/6/2003 0:00     Shipped       1         1     2003  ...
# 680    1/6/2003 0:00     Shipped       1         1     2003  ...
# 1267   1/6/2003 0:00     Shipped       1         1     2003  ...
# 728    1/9/2003 0:00     Shipped       1         1     2003  ...
# ...              ...         ...     ...       ...      ...  ...
# 2405  5/31/2005 0:00  In Process       2         5     2005  ...
# 393   5/31/2005 0:00  In Process       2         5     2005  ...
# 160   5/31/2005 0:00  In Process       2         5     2005  ...
# 780   5/31/2005 0:00  In Process       2         5     2005  ...
# 727   5/31/2005 0:00  In Process       2         5     2005  ...
#
#                       ADDRESSLINE1  ADDRESSLINE2       CITY STATE POSTALCODE  \
# 578       2304 Long Airport Avenue           NaN     Nashua    NH      62005
# 2024      2304 Long Airport Avenue           NaN     Nashua    NH      62005
# 680       2304 Long Airport Avenue           NaN     Nashua    NH      62005
# 1267      2304 Long Airport Avenue           NaN     Nashua    NH      62005
# 728                  Lyonerstr. 34           NaN  Frankfurt   NaN      60528
# ...                            ...           ...        ...   ...        ...
# 2405  67, rue des Cinquante Otages           NaN     Nantes   NaN      44000
# 393   67, rue des Cinquante Otages           NaN     Nantes   NaN      44000
# 160   67, rue des Cinquante Otages           NaN     Nantes   NaN      44000
# 780   67, rue des Cinquante Otages           NaN     Nantes   NaN      44000
# 727   67, rue des Cinquante Otages           NaN     Nantes   NaN      44000
#
#       COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 578       USA       NaN           Young          Valarie   Medium
# 2024      USA       NaN           Young          Valarie    Small
# 680       USA       NaN           Young          Valarie   Medium
# 1267      USA       NaN           Young          Valarie    Small
# 728   Germany      EMEA          Keitel           Roland   Medium
# ...       ...       ...             ...              ...      ...
# 2405   France      EMEA         Labrune           Janine    Small
# 393    France      EMEA         Labrune           Janine   Medium
# 160    France      EMEA         Labrune           Janine   Medium
# 780    France      EMEA         Labrune           Janine    Small
# 727    France      EMEA         Labrune           Janine   Medium
#
# [2823 rows x 25 columns]
